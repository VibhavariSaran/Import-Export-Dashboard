# %% [markdown]
# **Project Information**
#
# **Project - 02**
# * Project Title: Data Visualization (Dashboard) with Python using Pandas, Numpy, Matplotlib & Streamlit Libraries
# * Sumitted By: Vibhavari Saran(055055)
# * Program: PGDM-BDA-05
# * Facult: Prof Amarnath Mitra
# * Subject: Data Explration & Visualization using Python(DEVP)

# %% [markdown]
# **Description of Data**
#
# * Data Source & Size
#   * Data Source: The dataset used in this project provides detailed information about international trade transactions, with a focus on imports and exports.This dataset allows the user to explore various statistics such as mean, median, mode, maximum, and minimum values.The data likely comes from a business or organization involved in international trade either from a company's internal database or a global trade platform that tracks import and export transactions.
#   * Size: 15,000 observations (rows) and 16 variables (columns).
# Each record represents a single import/export transaction, and the data encompasses various transactions over months/years.
#   * Dataset Link(Kaggle link):  https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000
#
#
# * Data Type: The dataset is cross-sectional. It captures data from a single point in time for each transaction, providing a snapshot rather than tracking changes over time.
#
#
# * Data Dimension:
#   * Number of Variables: 16
#   * Number of Observations: 15,000
#
#
# * Data Variable Type:
#   * Text: Variables such as Transaction_ID, Country, Product, Import_Export, Date, Category, Port, Shipping_Method, Supplier, Customer, and Payment_Terms contain text data.
#   * Number:
#     * Integer: Quantity, Customs_Code, and Invoice_Number
#     * Decimal: Value (transaction value) and Weight (weight of the shipment)
#
#
# * Data Variable Category:
#   * Index: Transaction_ID (unique identifier for each transaction), Invoice_Number (unique invoice identification)
#   * Categorical Nominal Variable: Variables such as Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customer, and Payment_Terms that do not have an inherent order.
#     * Import/Export Status (Categorical Variable)*: This column distinguishes whether a transaction involves the importing or exporting of goods. This classification is crucial for the analysis as it allows the separation of inbound and outbound trade flows. It enables a comparison between the characteristics of imports versus exports, such as differences in transaction values or quantities.
# By analyzing the distribution of import and export transactions, businesses can identify trade imbalances (i.e., whether they import significantly more than they export or vice versa).
#     * Shipping Method (Categorical Variable): This column indicates the mode of transportation used to ship goods, such as air, sea, or land.
# The shipping method impacts delivery time, cost, and reliability. Different goods require different shipping methods based on factors like perishability, cost efficiency, and distance. Understanding the distribution of shipping methods used can help companies optimize their logistics by choosing cost-effective or faster shipping routes. Analyzing how often each method is used can also inform decisions on contract negotiations with logistics providers.
#     * Payment Terms (Categorical Variable): This column outlines the terms of payment for each transaction, such as pre-paid, post-paid, or credit terms.This Significes that the  payment terms directly affect cash flow and financial planning. Longer credit periods may affect liquidity, while upfront payments reduce financial risks.By examining the payment terms used for different transactions, businesses can optimize their financial policies. For instance, frequent use of credit terms may warrant tighter financial management, while prepaid terms offer more immediate cash flow benefits.
#
#   * Non-Categorical: Variables like Quantity, Value, Weight, and Customs_Code are numerical and continuous in nature, representing measurable quantities.

# %% [markdown]
# **Project Objectives | Problem Statements**
#
# The primary objective of the project is to leverage data visualization techniques to extract insights from a dataset related to global trade, specifically focusing on imports and exports. By using Python libraries like Pandas for data manipulation, Numpy for numerical analysis, Matplotlib and Seaborn for visualizations, and Streamlit for building interactive dashboards, the dashboard will help analyze trade data (Imports and Exports) by visualizing various aspects such as the relationship between quantity and value, changes in trade over time, and distribution of values across categories, suppliers, and countries, ect. The project aims to:
#
# 1. Understand Key Trade Dynamics:
#    - Analyze the relationship between trade quantities and their corresponding financial values, both for imports and exports.
#    - Identify trends in the data over time to understand how the trade value changes in different periods (monthly, seasonally, or annually).
#
# 2. Identify Patterns Across Product Categories:
#    - Understand the distribution of product values across different categories of goods being imported or exported. This can help in determining which categories have the most significant impact on overall trade value.
#
# 3. Provide Data-Driven Insights for Decision Making:
#    - Generate meaningful visualizations that can be used by trade managers or policymakers to optimize trade operations and create informed decisions about pricing, import-export strategies, and category prioritization.
#
# Overall, the goal is to take raw trade data and convert it into actionable insights through effective visualizations, facilitating a more strategic approach to managing imports and exports.riven business strategies.

# %% [markdown]
# **Analysis of Data**
#
# The analysis primarily revolves around multiple graph types that were used to analyze the dataset, each serving a specific purpose in understanding trade data related to imports and exports. Here’s an in-depth look at the various graph types employed in the analysis, their purposes, and the insights derived from them.
#
# 1. Scatter Plot: Relationship Between Quantity and Value (Imports vs. Exports)
#      - The scatter plot was used to understand the relationship between the quantity of goods and their total value, differentiating between imports and exports.
#      - It helps to visually represent whether the value increases proportionally with quantity or if there are other patterns such as diminishing returns.
#      - A positive correlation between quantity and value was observed for both imports and exports, meaning that generally, as the quantity increases, the value increases as well.
#      - However, the relationship is not perfectly linear, and distinct clusters for imports and exports were visible, suggesting that exports may have a different value-to-quantity ratio than imports.
#      - The clusters could imply that certain goods are more valuable per unit in exports than in imports or vice versa. This insight is important for understanding trade efficiency and profitability.
#      - Companies can use this relationship to determine optimal trade volumes. Understanding that exporting a certain quantity yields higher value can help in adjusting production or sourcing strategies.
#
# 2. Line Graph: Total Value of Imports and Exports Over Time
#      - The line graph was created to observe temporal trends in the value of imports and exports. It allows for the identification of peak periods for trade and potential seasonality.
#      - It helps in understanding how trade activities fluctuate over time, providing insights into whether certain months or seasons are better for imports or exports.
#      - The graph shows fluctuations in trade values over time, indicating possible seasonal trends. For instance, certain months show significant spikes in export values, potentially correlating with international demand cycles.
#      - The cyclical nature of imports suggests that certain goods are imported more consistently at specific times of the year. This could be due to market demands, seasonal products, or supply chain factors.
#      - Comparing the trends for imports and exports could reveal periods where one outperforms the other, offering opportunities to balance trade strategies or stock inventories accordingly.
#      - Businesses can align their inventory and production strategies with these temporal patterns. For example, increasing export activities during peak demand periods or preparing for high import periods could enhance profitability and efficiency.
#
# 3. Box Plot: Distribution of Product Values by Category
#      - The box plot was used to analyze the distribution of product values within different categories of goods. It helps in identifying which product categories are associated with high-value transactions and where the most variation occurs.
#      - This type of plot highlights the spread, median, and potential outliers in the data for each category.
#      - Some categories had a higher median value, indicating that goods within these categories tend to be of higher value compared to others. These could be considered premium categories.
#      - A few categories had a wide interquartile range and several outliers, which suggests a diverse mix of goods within the category. This could indicate that certain goods in the category are much more valuable than others, possibly due to factors like brand, quality, or demand.
#      - The presence of outliers in certain categories signals that there are exceptional transactions, either high-value deals or very low-value goods within the same category.
#      - High-value categories might be prioritized for further investment, as they offer better returns. Categories with high variability may require better standardization or pricing strategies to maximize consistency and profitability.
#      - Companies could focus on high-median value categories for premium offerings and investigate the reasons behind outliers in other categories to optimize pricing or explore new business opportunities.
#
# 4. Heatmap: Correlation Analysis
#      - A correlation matrix or heatmap is typically used to examine the relationship between various numeric features, such as Quantity, Value, and other relevant factors.
#      - Although not explicitly present in the extracted code, a heatmap could have been generated to quantify the strength of relationships between different variables.
#      - A heatmap would provide numeric insight into which variables are most strongly correlated. For example, it might show that Quantity and Value are moderately correlated, confirming the visual insights from the scatter plot.
#      - Category and Value might show little or no correlation in terms of raw numbers, suggesting that the value varies unpredictably within some categories.
#      - Understanding the strength of relationships between key variables allows businesses to make more informed decisions. For example, if Quantity and Value show a strong correlation, trade volume can be confidently increased for higher returns. If the correlation is weak, other factors like demand or market price fluctuations should be considered.
#
# 5. Bar Chart
#      - A bar chart could have been used to show the total value of imports and exports by category. This would allow for a quick comparison of the overall contribution of each category to trade volume.
#      - Bar charts offer a straightforward way to compare total contributions by category, helping to quickly identify the most lucrative product categories in terms of trade volume and value.
#      - Managers can quickly decide which categories to focus on for maximizing overall trade value. Those contributing the most to imports or exports can be further analyzed for efficiency improvements.imensions of the trade dataset, enabling data-driven decision-making in import-export operations.operations, pricing strategies, and resource allocation.

# %% [markdown]
# **Observations | Findings**
#
# The analysis of the dataset related to imports and exports yielded several key observations and findings, which can be used to derive valuable insights for businesses and policymakers. These observations stem from the different visualizations and analysis techniques applied to understand relationships between trade quantity, value, time, and product categories.
#
# 1. Relationship Between Quantity and Value
#    - Observation:
#      - The scatter plot showed a positive correlation between the quantity of goods traded and their total value. Generally, as the quantity of goods increases, the value tends to rise.
#      - The imports and exports form distinct clusters, suggesting that the relationship between quantity and value differs for these two trade types.
#
#    - Findings:
#      - For exports, higher quantities generally correspond to higher values, though there may be certain instances where small quantities have disproportionately high values, likely due to high-value goods or premium products.
#      - Imports show a similar trend, but the value per unit may be lower compared to exports, implying that the goods imported might be lower in value or have different market characteristics.
#      - The density of points in certain areas suggests that for both imports and exports, there are typical quantity-value ranges that most goods fall into, which might indicate standard trade practices for specific product types or markets.
#
# 2. Changes in Imports and Exports Over Time
#    - Observation:
#      - The line graph revealed fluctuations in the total value of imports and exports over time. Both imports and exports showed peaks and troughs, indicating variations in trade activity throughout the observed period.
#      - In some months, there were significant spikes in exports, while imports showed more of a cyclical pattern with regular increases and decreases over time.
#
#    - Findings:
#      - Seasonal Trends: There appear to be seasonal patterns in the data, with certain months seeing significantly higher trade activity, especially for exports. This could be related to international market demand or specific events (e.g., festivals, holidays, or fiscal cycles).
#      - Asymmetry in Trends: While imports show more consistent cycles, exports experience more sporadic peaks. This suggests that the export market may be influenced by external factors such as global demand or trade agreements, while imports may be tied to more regular, internal market needs.
#      - Export Spikes: The sharp increases in export values could be due to high-demand periods for certain goods or favorable trade conditions during those months.
#
# 3. Distribution of Product Values by Category
#    - Observation:
#      - The box plot highlighted significant differences in the distribution of product values across various categories. Some categories had a narrow range with consistent values, while others displayed wider ranges, indicating greater variability in the value of goods within those categories.
#      - A few categories had noticeable outliers, suggesting that there are occasional transactions with significantly higher or lower values compared to the majority.
#
#    - Findings:
#      - High-Value Categories: Some categories had a higher median value, suggesting that the goods within these categories are generally more expensive. These could be premium goods or products with higher global demand.
#      - Wide Variability: Categories with a wide interquartile range (IQR) indicate that there is a large spread in the value of goods within those categories. This could mean that the category contains both high-end and low-end products, or that market prices fluctuate significantly.
#      - Outliers: The presence of outliers suggests that there are occasional, highly valuable transactions or extreme low-value deals that are atypical compared to the general distribution within those categories.
#
# 4. Sample Size and Data Reduction
#    - Observation:
#      - A random sample of 3,001 records was used from the larger dataset to focus the analysis on a manageable portion. This sample was generated using a random state to ensure reproducibility.
#
#    - Findings:
#      - Even with the sample, clear patterns emerged in the data, which suggests that the dataset is representative enough for analysis without the need for processing the entire dataset.
#      - The random sampling approach provided a way to conduct meaningful analysis without being overwhelmed by large volumes of data, and still captured the essential trends.
#
# 5. Potential Correlations Between Variables
#    - Observation:
#      - Although a correlation analysis (e.g., heatmap) was not explicitly conducted in the provided code, the scatter plot and line graphs hint at potential relationships between variables such as quantity, value, and time.
#
#    - Findings:
#      - There is likely a moderate correlation between quantity and value based on the scatter plot, as increasing quantities tend to be associated with higher trade values. However, this relationship is not strictly linear, meaning other factors may be influencing trade values.
#      - Time also appears to influence the value of imports and exports, suggesting the presence of other variables such as market demand, seasonality, or geopolitical factors that may affect trade over time.

# %% [markdown]
# **Managerial Insights | Recommendations**
#
# The following insights derived from the analysis of import and export data provide actionable guidance for business decision-makers. These insights help in optimizing trade operations, resource allocation, and strategic planning.
#
# 1. Optimize Trade Volumes Based on Quantity-Value Relationships
#    - Managerial Insight:
#      - The analysis revealed a positive correlation between the quantity of goods and their value, but the relationship is not perfectly linear. Exports tend to command higher value per unit than imports, with certain clusters showing more lucrative opportunities for smaller quantities.
#      - Distinct clusters for imports and exports suggest that goods perform differently depending on their trade type. Exported goods may offer better returns on lower quantities, while imports could benefit from economies of scale.
#
#    - Recommendation:
#      - For exports, focus on optimizing the shipment of higher-value goods in smaller quantities where possible, especially in industries where quality or product exclusivity is more important than bulk trade.
#      - For imports, consider bulk purchasing strategies to reduce per-unit costs, especially in categories where value tends to increase proportionally with quantity.
#      - Use this insight to adjust pricing strategies: for exported goods, price can be increased for premium goods, while imports can be procured in larger quantities to reduce overall costs.
#
# 2. Leverage Seasonal Patterns and Cyclical Trends
#    - Managerial Insight:
#      - The time-series analysis showed cyclical and seasonal trends in both imports and exports. Certain months exhibited spikes in export values, while imports followed a more consistent cyclical pattern.
#      - These fluctuations suggest seasonality in trade activities, likely driven by external market demand, holidays, or fiscal cycles that can significantly impact international trade.
#
#    - Recommendation:
#      - Align inventory and production cycles with these seasonal trends. Increase export activities during peak months, particularly for goods that are in higher demand during specific seasons or events.
#      - For imports, plan purchasing schedules around the cyclical patterns to ensure that goods are stocked when needed without over-purchasing during low-demand months. This could help optimize storage costs and reduce stockpile expenses.
#      - Monitor global and domestic economic conditions that might influence demand spikes, such as trade agreements, tariffs, or international festivals.
#
# 3. Focus on High-Value Product Categories
#    - Managerial Insight:
#      - The box plot analysis revealed that some product categories consistently have a higher median value, while others exhibit a wide variability in pricing, with certain outliers indicating exceptional opportunities for high-value transactions.
#      - High-value categories are key to profitability, as they tend to offer better returns per unit traded.
#
#    - Recommendation:
#      - Prioritize high-value categories for both imports and exports. These categories should receive more attention in terms of marketing, trade negotiations, and resource allocation because they offer the greatest potential for profit.
#      - For categories with high variability, conduct a deeper analysis to understand the drivers behind the wide range of values. Is the variability due to different types of goods within the category, changing market conditions, or inconsistent quality?
#      - Investigate outliers to understand the potential for extraordinary high-value deals. If these outliers are repeatable, they could represent untapped opportunities for business expansion.
#
# 4. Manage Pricing Strategies Based on Product Variability
#    - Managerial Insight:
#      - The analysis showed that some product categories exhibit significant variability in pricing. Wide interquartile ranges (IQR) in the box plots suggest that goods in certain categories are subject to fluctuating market demand, inconsistent supply quality, or external economic factors.
#      - Outliers in these categories represent either underpriced or overpriced goods, indicating inefficiencies in pricing strategies.
#
#    - Recommendation:
#      - For categories with high variability, consider dynamic pricing models that reflect market conditions in real time. This strategy will help balance supply and demand effectively, ensuring that goods are priced competitively during peak and low periods.
#      - Conduct further analysis of pricing outliers to determine whether they represent anomalies or regular opportunities for premium pricing. If the latter, these goods could be isolated as luxury or specialized products with a dedicated marketing approach.
#      - Adjust procurement strategies for imports to avoid overpriced goods or seek alternative suppliers for goods showing frequent price fluctuations.
#
# 5. Streamline Supply Chain Operations by Analyzing Trade Patterns
#    - Managerial Insight:
#      - The cyclical nature of imports and the seasonal spikes in exports suggest that businesses could benefit from streamlining their supply chain operations. Better aligning inventory levels, transportation logistics, and procurement cycles with trade patterns could reduce costs and improve delivery times.
#
#    - Recommendation:
#      - Use the insights from trade timing to synchronize supply chain operations. Ensure that suppliers, transportation providers, and warehouses are prepared to handle peak export periods without causing delays.
#      - For imports, optimize order timing and inventory management to avoid excess storage costs or stockouts during peak demand. Working closely with logistics providers to anticipate cyclical changes in trade activity can help improve efficiency and reduce unnecessary costs.
#      - Monitor global supply chain disruptions (e.g., geopolitical events or natural disasters) and plan for contingencies to ensure continuity during uncertain periods.
#
# 6. Capitalize on Outliers and Anomalies
#    - Managerial Insight:
#      - The presence of outliers in product categories—transactions with significantly higher or lower values—points to potential untapped opportunities or inefficiencies. Understanding these outliers could lead to more strategic business decisions.
#
#    - Recommendation:
#      - For outliers showing high-value transactions, investigate whether these represent repeatable opportunities. If they do, they could be isolated into premium product lines with dedicated strategies for marketing, export, or import.
#      - For low-value outliers, conduct a cost-benefit analysis to determine whether these transactions are worth pursuing or if they represent inefficiencies in sourcing, pricing, or transportation.
#      - Use advanced analytics tools to flag anomalies in real-time, ensuring that outliers can be swiftly investigated for potential business opportunities or mitigated to avoid losses.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import streamlit as st
import seaborn as sns

# %%
file_path = (r"C:\Users\DELL\Downloads\archive (1)\Imports_Exports_Dataset.csv")
df = pd.read_csv(file_path)
df = pd.DataFrame(df)
df
# Out:
#                              Transaction_ID           Country    Product  \
# 0      e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1      f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2      eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3      f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4      e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
# ...                                     ...               ...        ...
# 14995  48df15a8-0823-4964-8c16-eddf2756f382  Marshall Islands        not
# 14996  31106617-94a6-4646-a001-5e7bd45abc26           Bermuda        air
# 14997  ee485839-fbde-4ced-af18-d98f5e863081          Tanzania       show
# 14998  5acd54aa-ec8c-4055-be8b-a447861a471c            Tuvalu         TV
# 14999  5cc039d0-a052-41fd-bfbb-c9f60c4565ac   North Macedonia       year
#
#       Import_Export  Quantity    Value        Date     Category  \
# ...

# %%
# Display the Dimensions of Data.
df.shape
# Out:
# (15000, 16)

# %%
# Display Data Information.
df.info
# Out:
# <bound method DataFrame.info of                              Transaction_ID           Country    Product  \
# 0      e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1      f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2      eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3      f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4      e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
# ...                                     ...               ...        ...
# 14995  48df15a8-0823-4964-8c16-eddf2756f382  Marshall Islands        not
# 14996  31106617-94a6-4646-a001-5e7bd45abc26           Bermuda        air
# 14997  ee485839-fbde-4ced-af18-d98f5e863081          Tanzania       show
# 14998  5acd54aa-ec8c-4055-be8b-a447861a471c            Tuvalu         TV
# 14999  5cc039d0-a052-41fd-bfbb-c9f60c4565ac   North Macedonia       year
#
# ...

# %%
# Createing an Unique Sample of 3001 Records using Student Roll Number as Random State.
sample= df.sample(n=3001, random_state=55055)
sample
# Out:
#                              Transaction_ID           Country    Product  \
# 7852   6c130b10-3a5d-4cd6-865c-be49ac5e822c         Venezuela      total
# 10932  9e4c8800-084f-4708-b072-d57fe676eb4b  Marshall Islands  community
# 7668   57d11a18-15d7-4a3a-8434-f31310d81218             Chile      place
# 12943  28633193-794a-4cb6-a493-b0b7aa06a543             Sudan       onto
# 5181   2d5633bb-fbec-4400-b71e-e27ce595e68f        Cape Verde     effect
# ...                                     ...               ...        ...
# 7797   d6f9a0a7-41b7-48f0-83b9-74e45bfd5bb4            Taiwan         so
# 8296   a2304023-f2bd-43d6-83ed-9b5e88d807c8             Ghana        son
# 353    e2091f49-e0a1-4d2b-857c-799848d002be              Mali     growth
# 4363   22d31e12-50aa-4729-b172-09cf29a60326           Algeria      where
# 9104   e68f2449-78f4-48d8-a0c3-47f0f30a5d9c          Cambodia       mean
#
#       Import_Export  Quantity    Value        Date   Category  \
# ...

# %%
# 1]What is the relationship between the quantity of goods and their total value for exports and imports?
# Scatter Plot: Quantity vs Value (Import/Export)
# X-axis: Quantity
# Y-axis: Value
plt.figure(figsize=(10, 6))
sns.scatterplot(data=sample, x='Quantity', y='Value', hue='Import_Export')
plt.title('Quantity vs Value (Import/Export)')
plt.show()

# %%
# 2]How do the total values of imports and exports change over time? 
# Line Graph: Total Value of Imports and Exports Over Time
sample['Date'] = pd.to_datetime(sample['Date'])
sample['Month'] =sample['Date'].dt.to_period('M')
monthly_data = sample.groupby(['Month', 'Import_Export'])['Value'].sum().unstack()
monthly_data.plot(kind='line', figsize=(10,6), marker='o')
plt.title('Imports vs Exports Over Time')
plt.xlabel('Month')
plt.ylabel('Transaction Value')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9704\882796097.py:3: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   sample['Date'] = pd.to_datetime(sample['Date'])

# %%
# 3]What is the distribution of product values by category?
# Box-Whisker Plot: Product Value Distribution by Category
# X-axis: Category
# Y-axis: Value
plt.figure(figsize=(12, 6))
sns.boxplot(data=sample, x='Category', y='Value')
plt.title('Product Value Distribution by Category')
plt.xticks(rotation=45)
plt.show()

# %%
# 4]Which country exports the highest quantity of goods?
# Bar Chart: Country with the Highest Quantity of Exports
# X-axis: Country
# Y-axis: Quantity (sum for each country)
sample_export = sample[sample['Import_Export'] == 'Export']
sample_export_grouped = sample_export.groupby('Country')['Quantity'].sum().reset_index()
top_10_exporting_countries = sample_export_grouped.sort_values(by='Quantity', ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_exporting_countries, x='Country', y='Quantity')
plt.title('Top 10 Countries by Export Quantity')
plt.xticks(rotation=45)
plt.show()

# %%
# 5]How is the distribution of the weight of goods shipped?
#  Histogram: Distribution of Shipping Weight
# X-axis: Weight
# Y-axis: Frequency
plt.figure(figsize=(10, 6))
sns.histplot(sample['Weight'], bins=20, kde=True)
plt.title('Distribution of Shipping Weight')
plt.show()

# %%
# 6]What is the distribution of the different shipping methods used?
# Pie Chart: Distribution of Shipping Methods
# Labels: Shipping Method
# Values: Count of each shipping method used
shipping_method_counts = sample['Shipping_Method'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(shipping_method_counts, labels=shipping_method_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Shipping Methods')
plt.show()

# %%
# 7]How does the weight of goods correlate with their quantity for different product categories?
# Scatter Plot: Weight vs Quantity (Category)
# X-axis: Weight
# Y-axis: Quantity
# Hue/Color: Category
plt.figure(figsize=(10, 6))
sns.scatterplot(data=sample, x='Weight', y='Quantity', hue='Category')
plt.title('Weight vs Quantity by Category')
plt.show()

# %%
# 8]What is the correlation between numerical variables like Quantity, Value, Weight, and Customs Code for all transactions?
numeric_cols = ['Quantity', 'Value', 'Weight', 'Customs_Code']
correlation_matrix = sample[numeric_cols].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Between Numerical Variables')
plt.show()

# %%
# 9] Which product categories account for the highest total value of exports?
# ar Chart: Highest Value of Exported Product Categories
# X-axis: Product Category
# Y-axis: Total Value (sum)
sample_export_grouped = sample_export.groupby('Category')['Value'].sum().reset_index().sort_values(by='Value', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(data=sample_export_grouped, x='Category', y='Value')
plt.title('Top Export Product Categories by Value')
plt.xticks(rotation=45)
plt.show()

# %%
# 10]What is the distribution of product values across different product categories?
# Histogram: Distribution of Product Values by Category
# X-axis: Value
# Y-axis: Frequency
# Hue/Color: Category 
plt.figure(figsize=(10, 6))
sns.histplot(data=sample, x='Value', hue='Category', bins=20, kde=True)
plt.title('Distribution of Product Values by Category')
plt.show()

# %%
# 11]What percentage of transactions is represented by each country?
# Pie Chart: Distribution of Transactions by Country
# Labels: Country
# Values: Number of Transactions
country_counts = sample['Country'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(country_counts, labels=country_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Transactions by Country')
plt.show()

# %%
# 12]What is the distribution of shipping weights for different shipping methods?
# Box-Whisker Plot: Weight Distribution by Shipping Method
# X-axis: Shipping Method
# Y-axis: Weight
# Grouping: Shipping Method
plt.figure(figsize=(10, 6))
sns.boxplot(data=sample, x='Shipping_Method', y='Weight')
plt.title('Weight Distribution by Shipping Method')
plt.show(1)

# %%
# 13]What are the top 5 customers by the value of goods purchased?
# Bar Chart: Top 5 Customers by Total Purchase Value
# X-axis: Customer
# Y-axis: Total Value (sum)
sample_customers = sample.groupby('Customer')['Value'].sum().reset_index().sort_values(by='Value', ascending=False).head(5)
plt.figure(figsize=(10, 6))
sns.barplot(data=sample_customers, x='Customer', y='Value')
plt.title('Top 5 Customers by Total Purchase Value')
plt.show()

# %%
# 14]What is the distribution of customs codes used in transactions?
# Histogram: Distribution of Customs Codes
# X-axis: Customs Code
# Y-axis: Frequency
plt.figure(figsize=(10, 6))
sns.histplot(sample['Customs_Code'], bins=20, kde=True)
plt.title('Distribution of Customs Codes')
plt.show()

# %%
# 15]What is the percentage distribution of payment terms used (e.g., Prepaid, Cash on Delivery, Net 60)?
# Pie Chart: Distribution of Payment Terms
# Labels: Payment Terms
# Values: Count of each payment term
payment_terms_counts = sample['Payment_Terms'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(payment_terms_counts, labels=payment_terms_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Payment Terms')
plt.show()

# %%
# 16]How does the total weight of goods exported and imported change over the years?
# Line Graph: Total Weight of Exports and Imports Over Time
# X-axis: Date (yearly/quarterly)
# Y-axis: Weight
sample['Date'] = pd.to_datetime(sample['Date'])
sample['Month'] = sample['Date'].dt.to_period('M')
monthly_data = sample.groupby(['Month', 'Import_Export'])['Value'].sum().unstack()
monthly_data.plot(kind='line', figsize=(10,6), marker='o')
plt.title('Imports vs Exports Over Time')
plt.xlabel('Month')
plt.ylabel('Transaction Value')
plt.show()

# %%
# 17]What is the distribution of values for transactions based on the payment terms?
# Box-Whisker Plot: Value Distribution by Payment Terms
# X-axis: Payment Terms
# Y-axis: Value
# Grouping: Payment Terms
plt.figure(figsize=(10, 6))
sns.boxplot(data=sample, x='Payment_Terms', y='Value')
plt.title('Value Distribution by Payment Terms')
plt.show()

# %%
# 18]Which are the top 5 suppliers by the number of transactions completed?
# Bar Chart: Top 5 Suppliers by Transaction Count
# X-axis: Supplier
# Y-axis: Number of Transactions
sample_suppliers = sample.groupby('Supplier')['Transaction_ID'].count().reset_index().sort_values(by='Transaction_ID', ascending=False).head(5)
plt.figure(figsize=(10, 6))
sns.barplot(data=sample_suppliers, x='Supplier', y='Transaction_ID')
plt.title('Top 5 Suppliers by Transaction Count')
plt.xticks(rotation=45)
plt.show()

# %%
# 19]What is the distribution of export versus import transactions in the dataset?
# Pie Chart: Import vs Export Transactions
# Labels: Import/Export
# Values: Count of transactions\
import_export_counts = sample['Import_Export'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(import_export_counts, labels=import_export_counts.index, autopct='%1.1f%%')
plt.title('Import vs Export Transactions')
plt.show()

# %%
# 20]What is the relationship between the total value of exports/imports and shipping methods across different countries?
last_5_countries = sample['Country'].unique()[-5:]
sample_last_5_countries = sample[sample['Country'].isin(last_5_countries)]
heatmap_data = sample_last_5_countries.pivot_table(values='Quantity', index='Country', columns='Category', aggfunc='sum')
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, cmap='Blues', annot=True, fmt='.1f')
plt.title('Quantity of Goods by Product Category and Last 5 Countries')
plt.xticks(rotation=45)
plt.show()
